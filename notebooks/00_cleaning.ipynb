# %% [markdown]
# # Video Game Sales Intelligence Suite
# ## Notebook 01: Data Understanding and Cleaning

# %% [markdown]
# ---

# %% [markdown]
# ### 1 - Importing Libraries and Setup Environment

# %%
import numpy as np
import pandas as pd
import matplotlib as plt

# %% [markdown]
# ### 2 - Load Raw Data

# %%
# Load the raw dataset
AC = pd.read_csv("../data/raw/combined_steam_categories.csv")
AD = pd.read_csv("../data/raw/application_developers.csv")
AG = pd.read_csv("../data/raw/application_genres.csv")
AP = pd.read_csv("../data/raw/grouped_application_platforms_data.csv")
APu = pd.read_csv("../data/raw/application_publishers.csv")
application = pd.read_csv("../data/raw/applications.csv")
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_26200\1299509596.py:7: DtypeWarning: Columns (0: required_age) have mixed types. Specify dtype option on import or set low_memory=False.
#   application = pd.read_csv("../data/raw/applications.csv")

# %% [markdown]
# #### the AI suggested multiple ways to load the datasets on of them is to ot put each dataset in a different variable
# #### but I think it is better to put all the datasets in one variable and then we can use it to clean the data and
# #### then we can use it to analyze the data.

# %%
# Load additional datasets
developers = pd.read_csv("../data/raw/developers.csv")
genres = pd.read_csv("../data/raw/genres_cleaned.csv")
publishers = pd.read_csv("../data/raw/publishers.csv")
reviews = pd.read_csv("../data/raw/reviews.csv")

# Combine all dataframes into a dictionary for easier management
dfs_dict = {
    'application_categories': AC,
    'application_developers': AD,
    'application_genres': AG,
    'application_platforms': AP,
    'application_publishers': APu,
    'applications': application,
    'developers': developers,
    'genres': genres,
    'publishers': publishers,
    'reviews': reviews
}

# Display basic info about each dataset
for name, df in dfs_dict.items():
    print(f"\n{name}:")
    print(f"  Shape: {df.shape}")
    print(f"  Columns: {list(df.columns)}")
# Out:
# application_categories:
#   Shape: (1077156, 3)
#   Columns: ['appid', 'category_id', 'name']
#
# application_developers:
#   Shape: (250817, 2)
#   Columns: ['appid', 'developer_id']
#
# application_genres:
#   Shape: (587515, 2)
#   Columns: ['appid', 'genre_id']
#
# application_platforms:
#   Shape: (239664, 2)
#   Columns: ['appid', 'platforms']
#
# application_publishers:
#   Shape: (223048, 2)
#   Columns: ['appid', 'publisher_id']
#
# applications:
#   Shape: (239664, 30)
#   Columns: ['appid', 'name', 'type', 'is_free', 'release_date', 'required_age', 'short_description', 'supported_languages', 'header_image', 'background', 'metacritic_score', 'recommendations_total', 'mat_supports_windows', 'mat_supports_mac', 'mat_supports_linux', 'mat_initial_price', 'mat_final_price', 'mat_discount_percent', 'mat_currency', 'mat_achievement_count', 'mat_pc_os_min', 'mat_pc_processor_min', 'mat_pc_memory_min', 'mat_pc_graphics_min', 'mat_pc_os_rec', 'mat_pc_processor_rec', 'mat_pc_memory_rec', 'mat_pc_graphics_rec', 'created_at', 'updated_at']
#
# developers:
#   Shape: (101226, 2)
#   Columns: ['id', 'name']
#
# genres:
#   Shape: (154, 2)
#   Columns: ['id', 'name']
#
# publishers:
#   Shape: (85699, 2)
#   Columns: ['id', 'name']
#
# reviews:
#   Shape: (1048148, 23)
#   Columns: ['recommendationid', 'appid', 'author_steamid', 'author_num_games_owned', 'author_num_reviews', 'author_playtime_forever', 'author_playtime_last_two_weeks', 'author_playtime_at_review', 'author_last_played', 'language', 'review_text', 'timestamp_created', 'timestamp_updated', 'voted_up', 'votes_up', 'votes_funny', 'weighted_vote_score', 'comment_count', 'steam_purchase', 'received_for_free', 'written_during_early_access', 'created_at', 'updated_at']

# %% [markdown]
# ##### if len(AC) > 0:: This checks if the table (e.g., Categories) actually has data in it. If it’s empty, it skips the merge to avoid errors.
# ##### suffixes=('', '_cat'): If both tables have columns with the same name (like a "name" column), Pandas needs to distinguish them. This tells Pandas to leave the master column name alone and add _cat to the end of the new column.

# %%
# Start with the main applications table as the base
combined_data = application.copy()

# Merge with application-relationship tables (these have appid)
# Merge application_categories
if len(AC) > 0:
    combined_data = combined_data.merge(AC, on='appid', how='left', suffixes=('', '_cat'))

# Merge application_developers
if len(AD) > 0:
    combined_data = combined_data.merge(AD, on='appid', how='left', suffixes=('', '_dev'))

# Merge application_genres
if len(AG) > 0:
    combined_data = combined_data.merge(AG, on='appid', how='left', suffixes=('', '_gen'))

# Merge application_platforms
if len(AP) > 0:
    combined_data = combined_data.merge(AP, on='appid', how='left', suffixes=('', '_plat'))

# Merge application_publishers
if len(APu) > 0:
    combined_data = combined_data.merge(APu, on='appid', how='left', suffixes=('', '_pub'))

print("Combined data shape:", combined_data.shape)
print("\nFirst 5 rows:")
print(combined_data.head())
# Out:
# Combined data shape: (3411597, 36)
#
# First 5 rows:
#    appid            name  type  is_free release_date required_age  \
# 0     10  Counter-Strike  game    False   2000-11-01            0
# 1     10  Counter-Strike  game    False   2000-11-01            0
# 2     10  Counter-Strike  game    False   2000-11-01            0
# 3     10  Counter-Strike  game    False   2000-11-01            0
# 4     10  Counter-Strike  game    False   2000-11-01            0
#
#                                    short_description  \
# 0  Play the world's number 1 online action game. ...
# 1  Play the world's number 1 online action game. ...
# 2  Play the world's number 1 online action game. ...
# 3  Play the world's number 1 online action game. ...
# 4  Play the world's number 1 online action game. ...
#
#                                  supported_languages  \
# 0  English<strong>*</strong>, French<strong>*</st...
# 1  English<strong>*</strong>, French<strong>*</st...
# 2  English<strong>*</strong>, French<strong>*</st...
# 3  English<strong>*</strong>, French<strong>*</st...
# 4  English<strong>*</strong>, French<strong>*</st...
#
#                                         header_image  \
# 0  https://shared.akamai.steamstatic.com/store_it...
# 1  https://shared.akamai.steamstatic.com/store_it...
# 2  https://shared.akamai.steamstatic.com/store_it...
# 3  https://shared.akamai.steamstatic.com/store_it...
# 4  https://shared.akamai.steamstatic.com/store_it...
#
#                                           background  ...  mat_pc_memory_rec  \
# 0  https://store.akamai.steamstatic.com/images/st...  ...                NaN
# 1  https://store.akamai.steamstatic.com/images/st...  ...                NaN
# 2  https://store.akamai.steamstatic.com/images/st...  ...                NaN
# 3  https://store.akamai.steamstatic.com/images/st...  ...                NaN
# 4  https://store.akamai.steamstatic.com/images/st...  ...                NaN
#
#    mat_pc_graphics_rec                        created_at  \
# 0                  NaN  2025-09-07 16:27:12.218587+00:00
# 1                  NaN  2025-09-07 16:27:12.218587+00:00
# 2                  NaN  2025-09-07 16:27:12.218587+00:00
# 3                  NaN  2025-09-07 16:27:12.218587+00:00
# 4                  NaN  2025-09-07 16:27:12.218587+00:00
#
#                          updated_at  category_id              name_cat  \
# 0  2025-09-29 02:01:37.107239+00:00         72.0    Color Alternatives
# 1  2025-09-29 02:01:37.107239+00:00         90.0                   Pvp
# 2  2025-09-29 02:01:37.107239+00:00        130.0        Family Sharing
# 3  2025-09-29 02:01:37.107239+00:00        133.0          Multi-Player
# 4  2025-09-29 02:01:37.107239+00:00        193.0  Keyboard Only Option
#
#    developer_id  genre_id                    platforms  publisher_id
# 0       59202.0     122.0  ['windows', 'mac', 'linux']       50182.0
# 1       59202.0     122.0  ['windows', 'mac', 'linux']       50182.0
# 2       59202.0     122.0  ['windows', 'mac', 'linux']       50182.0
# 3       59202.0     122.0  ['windows', 'mac', 'linux']       50182.0
# 4       59202.0     122.0  ['windows', 'mac', 'linux']       50182.0
#
# [5 rows x 36 columns]

# %% [markdown]
# #### Dataset Overview - Columns and Data Types

# %%
# Display data types and info about the combined dataset
print("Data Types:")
print(combined_data.dtypes)
print("\n" + "="*80)
print("\nDataset Info:")
print(combined_data.info())
# Out:
# Data Types:
# appid                      int64
# name                         str
# type                         str
# is_free                     bool
# release_date                 str
# required_age              object
# short_description            str
# supported_languages          str
# header_image                 str
# background                   str
# metacritic_score         float64
# recommendations_total    float64
# mat_supports_windows        bool
# mat_supports_mac            bool
# mat_supports_linux          bool
# mat_initial_price        float64
# mat_final_price          float64
# mat_discount_percent     float64
# mat_currency                 str
# mat_achievement_count    float64
# mat_pc_os_min                str
# mat_pc_processor_min         str
# mat_pc_memory_min            str
# mat_pc_graphics_min          str
# mat_pc_os_rec                str
# mat_pc_processor_rec         str
# mat_pc_memory_rec            str
# mat_pc_graphics_rec          str
# created_at                   str
# updated_at                   str
# category_id              float64
# name_cat                     str
# developer_id             float64
# genre_id                 float64
# platforms                    str
# publisher_id             float64
# dtype: object
#
# ================================================================================
#
# Dataset Info:
# <class 'pandas.DataFrame'>
# RangeIndex: 3411597 entries, 0 to 3411596
# Data columns (total 36 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   appid                  int64
#  1   name                   str
#  2   type                   str
#  3   is_free                bool
#  4   release_date           str
#  5   required_age           object
#  6   short_description      str
#  7   supported_languages    str
#  8   header_image           str
#  9   background             str
#  10  metacritic_score       float64
#  11  recommendations_total  float64
#  12  mat_supports_windows   bool
#  13  mat_supports_mac       bool
#  14  mat_supports_linux     bool
#  15  mat_initial_price      float64
#  16  mat_final_price        float64
#  17  mat_discount_percent   float64
#  18  mat_currency           str
#  19  mat_achievement_count  float64
#  20  mat_pc_os_min          str
#  21  mat_pc_processor_min   str
#  22  mat_pc_memory_min      str
#  23  mat_pc_graphics_min    str
#  24  mat_pc_os_rec          str
#  25  mat_pc_processor_rec   str
#  26  mat_pc_memory_rec      str
#  27  mat_pc_graphics_rec    str
#  28  created_at             str
#  29  updated_at             str
#  30  category_id            float64
#  31  name_cat               str
#  32  developer_id           float64
#  33  genre_id               float64
#  34  platforms              str
#  35  publisher_id           float64
# dtypes: bool(4), float64(10), int64(1), object(1), str(20)
# memory usage: 845.9+ MB
# None

# %%
combined_data.head()
# Out:
#    appid            name  type  is_free release_date required_age  \
# 0     10  Counter-Strike  game    False   2000-11-01            0
# 1     10  Counter-Strike  game    False   2000-11-01            0
# 2     10  Counter-Strike  game    False   2000-11-01            0
# 3     10  Counter-Strike  game    False   2000-11-01            0
# 4     10  Counter-Strike  game    False   2000-11-01            0
#
#                                    short_description  \
# 0  Play the world's number 1 online action game. ...
# 1  Play the world's number 1 online action game. ...
# 2  Play the world's number 1 online action game. ...
# 3  Play the world's number 1 online action game. ...
# 4  Play the world's number 1 online action game. ...
#
#                                  supported_languages  \
# 0  English<strong>*</strong>, French<strong>*</st...
# 1  English<strong>*</strong>, French<strong>*</st...
# 2  English<strong>*</strong>, French<strong>*</st...
# 3  English<strong>*</strong>, French<strong>*</st...
# 4  English<strong>*</strong>, French<strong>*</st...
#
#                                         header_image  \
# 0  https://shared.akamai.steamstatic.com/store_it...
# 1  https://shared.akamai.steamstatic.com/store_it...
# 2  https://shared.akamai.steamstatic.com/store_it...
# 3  https://shared.akamai.steamstatic.com/store_it...
# 4  https://shared.akamai.steamstatic.com/store_it...
#
#                                           background  ...  mat_pc_memory_rec  \
# 0  https://store.akamai.steamstatic.com/images/st...  ...                NaN
# 1  https://store.akamai.steamstatic.com/images/st...  ...                NaN
# 2  https://store.akamai.steamstatic.com/images/st...  ...                NaN
# 3  https://store.akamai.steamstatic.com/images/st...  ...                NaN
# 4  https://store.akamai.steamstatic.com/images/st...  ...                NaN
#
#    mat_pc_graphics_rec                        created_at  \
# 0                  NaN  2025-09-07 16:27:12.218587+00:00
# 1                  NaN  2025-09-07 16:27:12.218587+00:00
# 2                  NaN  2025-09-07 16:27:12.218587+00:00
# 3                  NaN  2025-09-07 16:27:12.218587+00:00
# 4                  NaN  2025-09-07 16:27:12.218587+00:00
#
#                          updated_at  category_id              name_cat  \
# 0  2025-09-29 02:01:37.107239+00:00         72.0    Color Alternatives
# 1  2025-09-29 02:01:37.107239+00:00         90.0                   Pvp
# 2  2025-09-29 02:01:37.107239+00:00        130.0        Family Sharing
# 3  2025-09-29 02:01:37.107239+00:00        133.0          Multi-Player
# 4  2025-09-29 02:01:37.107239+00:00        193.0  Keyboard Only Option
#
#    developer_id  genre_id                    platforms  publisher_id
# 0       59202.0     122.0  ['windows', 'mac', 'linux']       50182.0
# 1       59202.0     122.0  ['windows', 'mac', 'linux']       50182.0
# 2       59202.0     122.0  ['windows', 'mac', 'linux']       50182.0
# 3       59202.0     122.0  ['windows', 'mac', 'linux']       50182.0
# 4       59202.0     122.0  ['windows', 'mac', 'linux']       50182.0
#
# [5 rows x 36 columns]

# %%
combined_data = combined_data.drop(columns=['header_image', 'background', 'metacritic_score','mat_supports_window', 'mat_supports_mac', 'mat_supports_linux','mat_achievement_count',])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 combined_data = combined_data.drop(columns=['header_image', 'background', 'metacritic_score','mat_supports_window', 'mat_supports_mac', 'mat_supports_linux','mat_achievement_count',])
#
# File c:\Users\lenovo\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\frame.py:6288, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6130 def drop(
#    6131     self,
#    6132     labels: IndexLabel | ListLike = None,
#    (...)   6139     errors: IgnoreRaise = "raise",
#    6140 ) -> DataFrame | None:
#    6141     """
#    6142     Drop specified labels from rows or columns.
#    6143
#    (...)   6286             weight  1.0     0.8
#    6287     """
# -> 6288     return super().drop(
#    6289         labels=labels,
#    6290         axis=axis,
#    6291         index=index,
#    6292         columns=columns,
#    6293         level=level,
#    6294         inplace=inplace,
#    6295         errors=errors,
#    6296     )
#
# File c:\Users\lenovo\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\generic.py:4644, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4642 for axis, labels in axes.items():
#    4643     if labels is not None:
# -> 4644         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4646 if inplace:
#    4647     self._update_inplace(obj)
#
# File c:\Users\lenovo\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\generic.py:4686, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4684         new_axis = axis.drop(labels, level=level, errors=errors)
#    4685     else:
# -> 4686         new_axis = axis.drop(labels, errors=errors)
#    4687     indexer = axis.get_indexer(new_axis)
#    4689 # Case for non-unique axis
#    4690 else:
#
# File c:\Users\lenovo\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexes\base.py:7268, in Index.drop(self, labels, errors)
#    7266 if mask.any():
#    7267     if errors != "ignore":
# -> 7268         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7269     indexer = indexer[~mask]
#    7270 return self.delete(indexer)
#
# KeyError: "['mat_supports_window'] not found in axis"

# %%
#### Add Developer Names
#combined_data = combined_data.merge(developers, left_on='developer_id', right_on='id', how='left', suffixes=('', '_dev_name'))

#### Add Genre Names
#combined_data = combined_data.merge(genres, left_on='genre_id', right_on='id', how='left', suffixes=('', '_gen_name'))

#### Add Publisher Names
#combined_data = combined_data.merge(publishers, left_on='publisher_id', right_on='id', how='left', suffixes=('', '_pub_name'))

# %%
cols_to_drop = [col for col in combined_data.columns if col == 'id']
combined_data = combined_data.drop(columns=cols_to_drop)

# Rename the 'name' columns to be more descriptive
combined_data = combined_data.rename(columns={
    'name': 'category_name',
    'name_dev_name': 'developer_name',
    'name_gen_name': 'genre_name',
    'name_plat_name': 'platform_name',
    'name_pub_name': 'publisher_name'
})

# %%
print("Final Table Preview:")
combined_data.head()
# Out:
# Final Table Preview:
#    appid   category_name  type  is_free release_date required_age  \
# 0     10  Counter-Strike  game    False   2000-11-01            0
# 1     10  Counter-Strike  game    False   2000-11-01            0
# 2     10  Counter-Strike  game    False   2000-11-01            0
# 3     10  Counter-Strike  game    False   2000-11-01            0
# 4     10  Counter-Strike  game    False   2000-11-01            0
#
#                                    short_description  \
# 0  Play the world's number 1 online action game. ...
# 1  Play the world's number 1 online action game. ...
# 2  Play the world's number 1 online action game. ...
# 3  Play the world's number 1 online action game. ...
# 4  Play the world's number 1 online action game. ...
#
#                                  supported_languages  \
# 0  English<strong>*</strong>, French<strong>*</st...
# 1  English<strong>*</strong>, French<strong>*</st...
# 2  English<strong>*</strong>, French<strong>*</st...
# 3  English<strong>*</strong>, French<strong>*</st...
# 4  English<strong>*</strong>, French<strong>*</st...
#
#                                         header_image  \
# 0  https://shared.akamai.steamstatic.com/store_it...
# 1  https://shared.akamai.steamstatic.com/store_it...
# 2  https://shared.akamai.steamstatic.com/store_it...
# 3  https://shared.akamai.steamstatic.com/store_it...
# 4  https://shared.akamai.steamstatic.com/store_it...
#
#                                           background  ...  \
# 0  https://store.akamai.steamstatic.com/images/st...  ...
# 1  https://store.akamai.steamstatic.com/images/st...  ...
# 2  https://store.akamai.steamstatic.com/images/st...  ...
# 3  https://store.akamai.steamstatic.com/images/st...  ...
# 4  https://store.akamai.steamstatic.com/images/st...  ...
#
#                name_cat  developer_id  genre_id                    platforms  \
# 0    Color Alternatives       59202.0     122.0  ['windows', 'mac', 'linux']
# 1                   Pvp       59202.0     122.0  ['windows', 'mac', 'linux']
# 2        Family Sharing       59202.0     122.0  ['windows', 'mac', 'linux']
# 3          Multi-Player       59202.0     122.0  ['windows', 'mac', 'linux']
# 4  Keyboard Only Option       59202.0     122.0  ['windows', 'mac', 'linux']
#
#    publisher_id  developer_name  id_gen_name  genre_name id_pub_name  \
# 0       50182.0           Valve        122.0      Action     50182.0
# 1       50182.0           Valve        122.0      Action     50182.0
# 2       50182.0           Valve        122.0      Action     50182.0
# 3       50182.0           Valve        122.0      Action     50182.0
# 4       50182.0           Valve        122.0      Action     50182.0
#
#    publisher_name
# 0           Valve
# 1           Valve
# 2           Valve
# 3           Valve
# 4           Valve
#
# [5 rows x 41 columns]

# %%
combined_data.describe()
# Out:
#               appid  metacritic_score  recommendations_total  \
# count  3.411597e+06     106893.000000           4.935110e+05
# mean   1.962951e+06         75.442358           7.884749e+03
# std    1.086772e+06          9.640040           6.145918e+04
# min    1.000000e+01          6.000000           1.010000e+02
# 25%    1.020830e+06         70.000000           1.990000e+02
# 50%    1.886980e+06         77.000000           4.770000e+02
# 75%    2.886830e+06         82.000000           1.793000e+03
# max    3.996190e+06         97.000000           4.661011e+06
#
#        mat_initial_price  mat_final_price  mat_discount_percent  \
# count       2.256275e+06     2.256275e+06          2.256275e+06
# mean        3.547090e+04     3.254364e+04          5.768878e+00
# std         1.127817e+06     1.040358e+06          1.841345e+01
# min         5.000000e+01     4.400000e+01          0.000000e+00
# 25%         2.990000e+02     2.990000e+02          0.000000e+00
# 50%         5.990000e+02     5.990000e+02          0.000000e+00
# 75%         1.299000e+03     1.199000e+03          0.000000e+00
# max         8.990000e+07     8.910000e+07          9.500000e+01
#
#        mat_achievement_count   category_id  developer_id      genre_id  \
# count           1.087482e+06  3.393381e+06  3.392269e+06  3.336285e+06
# mean            3.683220e+01  1.682897e+02  4.946821e+04  6.461926e+01
# std             1.720077e+02  9.363413e+01  2.925654e+04  4.908736e+01
# min             0.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%             1.100000e+01  1.250000e+02  2.369400e+04  3.100000e+01
# 50%             2.000000e+01  1.420000e+02  4.983300e+04  3.200000e+01
# 75%             3.700000e+01  2.010000e+02  7.467500e+04  1.220000e+02
# max             9.821000e+03  5.330000e+02  1.015880e+05  1.670000e+02
#
#        publisher_id   id_gen_name   id_pub_name
# count  3.118419e+06  3.336285e+06  3.118419e+06
# mean   4.238560e+04  6.461926e+01  4.238560e+04
# std    2.476430e+04  4.908736e+01  2.476430e+04
# min    1.000000e+00  1.000000e+00  1.000000e+00
# 25%    2.068350e+04  3.100000e+01  2.068350e+04
# 50%    4.220300e+04  3.200000e+01  4.220300e+04
# 75%    6.432300e+04  1.220000e+02  6.432300e+04
# max    8.600400e+04  1.670000e+02  8.600400e+04

# %% [markdown]
# The appid column has approximately $4.95 \times 10^6$ entries, while metacritic_score only has $1.91 \times 10^5$.
# ### This indicates a high volume of null values in the scores column.
#
# In columns like mat_initial_price, the maximum value is exponentially higher than the 75% mark.
# ### This suggests the presence of outliers or potential data entry errors that could skew statistical models
#
# In metacritic_score, the median (77) is quite close to the 75th percentile (82), indicating that the data is concentrated toward higher ratings.
# ### This helps determine if the data is normally distributed or skewed
#
# Columns such as developer_id, genre_id, and platform_id show mean and standard deviation values.
# ### Since these are categorical identifiers (IDs) and not actual numerical measurements, these statistics are mathematically irrelevant. This serves as a reminder to convert these columns to object or category types to avoid logical errors in modeling.
#
# The std (Standard Deviation) row measures how spread out the numbers are
# High variance in recommendations_total shows a massive gap in popularity across the dataset
# ### High standard deviation often suggests that feature scaling (like Normalization or Standardization) may be necessary before training a model
